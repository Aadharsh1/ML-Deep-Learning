# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
notebook_path = '/content/drive/MyDrive/Colab Notebooks/run2.ipynb'

# %%
project_name = 'Simple Experiments'
run_name = 'Fashion_Mnist_run2'
